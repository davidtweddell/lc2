# %%
# reload magics
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datasets
from project_modules.io import load_dataset_to_df
from project_modules.classifcation import classify_MP,getXY, boruta_fs
from project_modules.utils import MPutils
from sklearn.ensemble import RandomForestClassifier
import multiprocessing
from sklearn.model_selection import cross_val_score
import cupy as cp
from datetime import datetime

from tqdm.notebook import tqdm
from copy import deepcopy

# from project_modules.utils import get_logger
# logger = get_logger("log-data-combine-split.log")
# # read the parameter file

# from project_modules.utils import read_parameters
# parms = read_parameters("/Users/david/projects/lc-project-data/project.yaml")

pd.options.display.max_columns = None
pd.options.display.max_rows = 50

# %%
lScorersBinary = [
    "accuracy",
    "balanced_accuracy",
    "roc_auc",
    "f1",
    "recall",
    "sensitivity",
    "specificity",
    "precision",
    # "average_precision",
    "NPV",
    "PPV",
    # "neg_mean_squared_error",
]
lResCol = [
    "Title",
    "cv",
    "param_clf",
    "param_clf__max_depth",
    "param_clf__n_estimators",
    "param_clf__random_state",
    # "param_clf__max_iter",
    "mean_test_accuracy",
    "mean_test_balanced_accuracy",
    "mean_test_roc_auc",
    "mean_test_f1",
    "mean_test_recall",
    "mean_test_sensitivity",
    "mean_test_specificity",
    "mean_test_precision",
    "mean_test_NPV",
    "mean_test_PPV",
]

# %%
site_name_dict = {1: "LDN", 2: "MTL", 3: "SAN", 4: "RIO", 5: "LUS", 6: "CA", 7: "NA"}
status_name_dict = {0: "HC", 1: "LC_NEG", 2: "LC_POS"}

# %% [markdown]
# # Combine Results

# %%
import glob

path = "OUTPUT/MP/05-classifiers/DataV3"
files = glob.glob(path + '/*/CA*.csv')
# files = files+glob.glob(path + "/*/FS*.csv")
files = files + glob.glob(path + "/*/Val*.csv")
files = files+glob.glob(path+'/*/CLFRun*.csv')
files = [x for x in files if 'selcol' not in x.lower()]

print(files)
print(len(files))
# Out:
# ['OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC_SITE5/CA_dfcmpltPreLC_SITE5_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC_SITE5/CA_dfcmpltPreLC_SITE5_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmplt_SITE2/CA_dfcmplt_SITE2_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmplt_SITE2/CA_dfcmplt_SITE2_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC3_SITE3/CA_dfcmpltPreLC3_SITE3_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC3_SITE3/CA_dfcmpltPreLC3_SITE3_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC4_SITE4/CA_dfcmpltPreLC4_SITE4_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC4_SITE4/CA_dfcmpltPreLC4_SITE4_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC3_SITE4/CA_dfcmpltPreLC3_SITE4_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC3_SITE4/CA_dfcmpltPreLC3_SITE4_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC3_SITE5/CA_dfcmpltPreLC3_SITE5_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC3_SITE5/CA_dfcmpltPreLC3_SITE5_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC2_SITE2/CA_dfcmpltPreLC2_SITE2_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC2_SITE2/CA_dfcmpltPreLC2_SITE2_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC2_SITE4/CA_dfcmpltPreLC2_SITE4_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC2_SITE4/CA_dfcmpltPreLC2_SITE4_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC2/CA_dfcmpltPreLC2_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC2/CA_dfcmpltPreLC2_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC2_SITE7/CA_dfcmpltPreLC2_SITE7_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC2_SITE7/CA_dfcmpltPreLC2_SITE7_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmplt_SITE3/CA_dfcmplt_SITE3_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmplt_SITE3/CA_dfcmplt_SITE3_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC3_SITE2/CA_dfcmpltPreLC3_SITE2_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC3_SITE2/CA_dfcmpltPreLC3_SITE2_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC4_SITE6/CA_dfcmpltPreLC4_SITE6_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC4_SITE6/CA_dfcmpltPreLC4_SITE6_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC_SITE4/CA_dfcmpltPreLC_SITE4_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC_SITE4/CA_dfcmpltPreLC_SITE4_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC4_SITE1/CA_dfcmpltPreLC4_SITE1_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC4_SITE1/CA_dfcmpltPreLC4_SITE1_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC_SITE3/CA_dfcmpltPreLC_SITE3_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC_SITE3/CA_dfcmpltPreLC_SITE3_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC3/CA_dfcmpltPreLC3_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC3/CA_dfcmpltPreLC3_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmplt/CA_dfcmplt_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmplt/CA_dfcmplt_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmplt_SITE1/CA_dfcmplt_SITE1_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmplt_SITE1/CA_dfcmplt_SITE1_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC2_SITE3/CA_dfcmpltPreLC2_SITE3_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC2_SITE3/CA_dfcmpltPreLC2_SITE3_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC_SITE2/CA_dfcmpltPreLC_SITE2_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC_SITE2/CA_dfcmpltPreLC_SITE2_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC4_SITE3/CA_dfcmpltPreLC4_SITE3_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC4_SITE3/CA_dfcmpltPreLC4_SITE3_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmplt_SITE4/CA_dfcmplt_SITE4_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmplt_SITE4/CA_dfcmplt_SITE4_Full.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC4_SITE5/CA_dfcmpltPreLC4_SITE5_Holdout.csv', 'OUTPUT/MP/05-classifiers/DataV3/dfcmpltPreLC4 ...
# 164

# %%
ldf = []
for i in files:
    ldf.append(pd.read_csv(i))

# %%
dfRes = pd.concat(ldf)

# %%
def changeSite(x):
    if pd.isnull(x):
        return np.nan
    if 'SITE7' in x:
        return 'NorthAmerica'
    if 'SITE6' in x:
        return 'Canada'
    if 'SITE5' in x:
        return 'LUS'
    if 'SITE4' in x:
        return 'RIO'
    if 'SITE3' in x:
        return 'SAN'
    if 'SITE2' in x:
        return 'MTL'
    if 'SITE1' in x:
        return 'LDN'
    return "Global"

# %%
dfRes
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.090703      0.014567         0.020051        0.003527
# 1         0.891907      0.154319         0.081418        0.001751
# 2         0.106432      0.004907         0.022866        0.000483
# 3         0.877277      0.207132         0.069527        0.018180
# 4         0.123478      0.018741         0.022679        0.000614
# ..             ...           ...              ...             ...
# 323       0.274957      0.018386         0.019865        0.002239
# 324       0.037617      0.006332         0.014070        0.001392
# 325       0.288209      0.009185         0.019806        0.001338
# 326       0.022130      0.005153         0.012098        0.002920
# 327       0.173386      0.022925         0.014155        0.000713
#
#                                              param_clf  param_clf__max_depth  \
# 0                             RandomForestClassifier()                   3.0
# 1                             RandomForestClassifier()                   3.0
# 2                             RandomForestClassifier()                   6.0
# 3                             RandomForestClassifier()                   6.0
# 4                             RandomForestClassifier()                  10.0
# ..                                                 ...                   ...
# 323  XGBClassifier(base_score=None, booster=None, c...                  10.0
# 324  XGBClassifier(base_score=None, booster=None, c...                  15.0
# 325  XGBClassifier(base_score=None, booster=None, c...                  15.0
# 326  XGBClassifier(base_score=None, booster=None, c...                   NaN
# 327  XGBClassifier(base_score=None, booster=None, c...                   NaN
#
#      param_clf__n_estimators  param_clf__random_state  param_clf__max_iter  \
# 0                      100.0                     42.0                  NaN
# 1                     1000.0                     42.0                  NaN
# 2                      100.0                     42.0                  NaN
# 3                     1000.0                     42.0                  NaN
# 4                      100.0                     42.0                  NaN
# ..                       ...                      ...                  ...
# 323                   1000.0                     42.0                  NaN
# 324                    100.0                     42.0                  NaN
# 325                   1000.0                     42.0                  NaN
# 326                    100.0                     42.0                  NaN
# 327                   1000.0                     42.0                  NaN
#
#      param_clf__learning_rate  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ..                        ...
# 323                       1.0
# 324                       1.0
# 325                       1.0
# 326                       1.0
# 327                       1.0
#
#                                                 params  split0_test_accuracy  \
# 0    {'clf': RandomForestClassifier(), 'clf__max_de...              0.775510
# 1    {'clf': RandomForestClassifier(), 'clf__max_de...              0.775510
# 2    {'clf': RandomForestClassifier(), 'clf__max_de...              0.775510
# 3    {'clf': RandomForestClassifier(), 'clf__max_de...              0.775510
# 4    {'clf': RandomForestClassifier(), 'clf__max_de...              0.755102
# ..                                                 ...                   ...
# 323  {'clf': XGBClassifier(base_score=None, booster...              0.648438
# 324  {'clf': XGBClassifier(base_score=None, booster...              0.656250
# 325  {'clf': XGBClassifier(base_score=None, booster...              0.640625
# 326  {'clf': XGBClassifier(base_score=None, booster...              0.609375
# 327  {'clf': XGBClassifier(base_score=None, booster...              0.664062
#
#      split1_test_accuracy  split2_test_accuracy  split3_test_accuracy  \
# 0                0.812500              0.770833              0.770833
# 1                0.812500              0.770833              0.770833
# 2                0.812500              0.770833              0.770833
# 3                0.812500              0.770833              0.770833
# 4                0.812500              0.770833              0.770833
# ..                    ...                   ...                   ...
# 323              0.585938              0.664062              0.656250
# 324              0.593750              0.687500              0.648438
# 325              0.585938              0.671875              0.664062
# 326              0.601562              0.679688              0.648438
# 327              0.570312              0.679688              0.656250
#
#      split4_test_accuracy  mean_test_accuracy  std_test_accuracy  \
# 0                0.770833            0.780102           0.016300
# 1                0.770833            0.780102           0.016300
# 2                0.770833            0.780102           0.016300
# 3                0.770833            0.780102           0.016300
# 4                0.750000            0.771854           0.021965
# ..                    ...                 ...                ...
# 323              0.617188            0.634375           0.028980
# 324              0.609375            0.639062           0.033657
# 325              0.609375            0.634375           0.032551
# 326              0.601562            0.628125           0.031093
# 327              0.609375            0.635938           0.040323
#
#      rank_test_accuracy  split0_test_balanced_accuracy  \
# 0                     1                       0.500000
# 1                     1                       0.500000
# 2                     1                       0.500000
# 3                     1                       0.500000
# 4                    10                       0.486842
# ..                  ...                            ...
# 323                  31                       0.586627
# 324                  23                       0.598823
# 325                  31                       0.587328
# 326                  39                       0.551444
# 327                  29                       0.591674
#
#      split1_test_balanced_accuracy  split2_test_balanced_accuracy  \
# 0                         0.550000                       0.500000
# 1                         0.550000                       0.500000
# 2                         0.550000                       0.500000
# 3                         0.550000                       0.500000
# 4                         0.550000                       0.500000
# ..                             ...                            ...
# 323                       0.508410                       0.585226
# 324                       0.527054                       0.615363
# 325                       0.514858                       0.597421
# 326                       0.539249                       0.603168
# 327                       0.509812                       0.603168
#
#      split3_test_balanced_accuracy  split4_test_balanced_accuracy  \
# 0                         0.500000                       0.500000
# 1                         0.500000                       0.500000
# 2                         0.500000                       0.500000
# 3                         0.500000                       0.500000
# 4                         0.500000                       0.518428
# ..                             ...                            ...
# 323                       0.605271                       0.537847
# 324                       0.599523                       0.538548
# 325                       0.617466                       0.532100
# 326                       0.599523                       0.519905
# 327                       0.605271                       0.532100
#
#      mean_test_balanced_accuracy  std_test_balanced_accuracy  \
# 0                       0.510000                    0.020000
# 1                       0.510000                    0.020000
# 2                       0.510000                    0.020000
# 3                       0.510000                    0.020000
# 4                       0.511054                    0.021917
# ..                           ...                         ...
# 323                     0.564676                    0.035882
# 324                     0.575862                    0.035839
# 325                     0.569835                    0.039451
# 326                     0.562658                    0.033171
# 327                     0.568405                    0.039649
#
#      rank_test_balanced_accuracy  split0_test_roc_auc  split1_test_roc_auc  \
# 0                             33             0.590909             0.786842
# 1                             33             0.593301             0.784211
# 2                             33             0.578947             0.734211
# 3                             33             0.581340             0.773684
# 4                             32             0.571770             0.786842
# ..                           ...                  ...                  ...
# 323                           34             0.653350             0.578217
# 324                           15             0.655032             0.582142
# 325                           25             0.653911             0.569807
# 326                           36             0.652229             0.592515
# 327                           26             0.642977             0.565882
#
#      split2_test_roc_auc  split3_test_roc_auc  split4_test_roc_auc  \
# 0               0.658477             0.717445             0.710074
# 1               0.616708             0.714988             0.756757
# 2               0.535627             0.712531             0.700246
# 3               0.601966             0.707617             0.710074
# 4               0.601966             0.702703             0.722359
# ..                   ...                  ...                  ...
# 323             0.606392             0.646201             0.534623
# 324             0.622932             0.641155             0.532100
# 325             0.605271             0.639753             0.534062
# 326             0.626857             0.649565             0.542332
# 327             0.614242             0.654051             0.538267
#
#      mean_test_roc_auc  std_test_roc_auc  rank_test_roc_auc  split0_test_f1  \
# 0             0.692749          0.065283                  2        0.000000
# 1             0.693193          0.075668                  1        0.000000
# 2             0.652312          0.079535                  9        0.000000
# 3             0.674936          0.072303                  4        0.000000
# 4             0.677128          0.079356                  3        0.000000
# ..                 ...               ...                ...             ...
# 323           0.603757          0.044045                 38        0.430380
# 324           0.606672          0.044620                 37        0.450000
# 325           0.600561          0.044209                 41        0.439024
# 326           0.612700          0.041185                 30        0.390244
# 327           0.603084          0.044494                 39        0.426667
#
#      split1_test_f1  split2_test_f1  split3_test_f1  split4_test_f1  \
# 0          0.181818        0.000000        0.000000        0.000000
# 1          0.181818        0.000000        0.000000        0.000000
# 2          0.181818        0.000000        0.000000        0.000000
# 3          0.181818        0.000000        0.000000        0.000000
# 4          0.181818        0.000000        0.000000        0.142857
# ..              ...             ...             ...             ...
# 323        0.311688        0.410959        0.463415        0.346667
# 324        0.350000        0.459459        0.457831        0.358974
# 325        0.329114        0.432432        0.481928        0.342105
# 326        0.370370        0.438356        0.457831        0.320000
# 327        0.337349        0.438356        0.463415        0.342105
#
#      mean_test_f1  std_test_f1  rank_test_f1  split0_test_recall  \
# 0        0.036364     0.072727            34            0.000000
# 1        0.036364     0.072727            34            0.000000
# 2        0.036364     0.072727            34            0.000000
# 3        0.036364     0.072727            34            0.000000
# 4        0.064935     0.080478            33            0.000000
# ..            ...          ...           ...                 ...
# 323      0.392622     0.055562            27            0.414634
# 324      0.415253     0.049799             8            0.439024
# 325      0.404921     0.059233            14            0.439024
# 326      0.395360     0.049155            25            0.390244
# 327      0.401578     0.051900            18            0.390244
#
#      split1_test_recall  split2_test_recall  split3_test_recall  \
# 0              0.100000            0.000000            0.000000
# 1              0.100000            0.000000            0.000000
# 2              0.100000            0.000000            0.000000
# 3              0.100000            0.000000            0.000000
# 4              0.100000            0.000000            0.000000
# ..                  ...                 ...                 ...
# 323            0.292683            0.365854            0.463415
# 324            0.341463            0.414634            0.463415
# 325            0.317073            0.390244            0.487805
# 326            0.365854            0.390244            0.463415
# 327            0.341463            0.390244            0.463415
#
#      split4_test_recall  mean_test_recall  std_test_recall  rank_test_recall  \
# 0              0.000000          0.020000         0.040000                34
# 1              0.000000          0.020000         0.040000                34
# 2              0.000000          0.020000         0.040000                34
# 3              0.000000          0.020000         0.040000                34
# 4              0.090909          0.038182         0.046851                33
# ..                  ...               ...              ...               ...
# 323            0.317073          0.370732         0.062470                22
# 324            0.341463          0.400000         0.050223                 6
# 325            0.317073          0.390244         0.067239                 9
# 326            0.292683          0.380488         0.054756                14
# 327            0.317073          0.380488         0.050223                14
#
#      split0_test_sensitivity  split1_test_sensitivity  \
# 0                   0.000000                 0.100000
# 1                   0.000000                 0.100000
# 2                   0.000000                 0.100000
# 3                   0.000000                 0.100000
# 4                   0.000000                 0.100000
# ..                       ...                      ...
# 323                 0.414634                 0.292683
# 324                 0.439024                 0.341463
# 325                 0.439024                 0.317073
# 326                 0.390244                 0.365854
# 327                 0.390244                 0.341463
#
#      split2_test_sensitivity  split3_test_sensitivity  \
# 0                   0.000000                 0.000000
# 1                   0.000000                 0.000000
# 2                   0.000000                 0.000000
# 3                   0.000000                 0.000000
# 4                   0.000000                 0.000000
# ..                       ...                      ...
# 323                 0.365854                 0.463415
# 324                 0.414634                 0.463415
# 325                 0.390244                 0.487805
# 326                 0.390244                 0.463415
# 327                 0.390244                 0.463415
#
#      split4_test_sensitivity  mean_test_sensitivity  std_test_sensitivity  \
# 0                   0.000000               0.020000              0.040000
# 1                   0.000000               0.020000              0.040000
# 2                   0.000000               0.020000              0.040000
# 3                   0.000000               0.020000              0.040000
# 4                   0.090909               0.038182              0.046851
# ..                       ...                    ...                   ...
# 323                 0.317073               0.370732              0.062470
# 324                 0.341463               0.400000              0.050223
# 325                 0.317073               0.390244              0.067239
# 326                 0.292683               0.380488              0.054756
# 327                 0.317073               0.380488              0.050223
#
#      rank_test_sensitivity  split0_test_specificity  split1_test_specificity  \
# 0                       34                 1.000000                 1.000000
# 1                       34                 1.000000                 1.000000
# 2                       34                 1.000000                 1.000000
# 3                       34                 1.000000                 1.000000
# 4                       33                 0.973684                 1.000000
# ..                     ...                      ...                      ...
# 323                     22                 0.758621                 0.724138
# 324                      6                 0.758621                 0.712644
# 325                      9                 0.735632                 0.712644
# 326                     14                 0.712644                 0.712644
# 327                     14                 0.793103                 0.678161
#
#      split2_test_specificity  split3_test_specificity  \
# 0                   1.000000                 1.000000
# 1                   1.000000                 1.000000
# 2                   1.000000                 1.000000
# 3                   1.000000                 1.000000
# 4                   1.000000                 1.000000
# ..                       ...                      ...
# 323                 0.804598                 0.747126
# 324                 0.816092                 0.735632
# 325                 0.804598                 0.747126
# 326                 0.816092                 0.735632
# 327                 0.816092                 0.747126
#
#      split4_test_specificity  mean_test_specificity  std_test_specificity  \
# 0                   1.000000               1.000000              0.000000
# 1                   1.000000               1.000000              0.000000
# 2                   1.000000               1.000000              0.000000
# 3                   1.000000               1.000000              0.000000
# 4                   0.945946               0.983926              0.021552
# ..                       ...                    ...                   ...
# 323                 0.758621               0.758621              0.026211
# 324                 0.735632               0.751724              0.035316
# 325                 0.747126               0.749425              0.030324
# 326                 0.747126               0.744828              0.038053
# 327                 0.747126               0.756322              0.047336
#
#      rank_test_specificity  split0_test_precision  split1_test_precision  \
# 0                        1               0.000000               1.000000
# 1                        1               0.000000               1.000000
# 2                        1               0.000000               1.000000
# 3                        1               0.000000               1.000000
# 4                       10               0.000000               1.000000
# ..                     ...                    ...                    ...
# 323                     23               0.447368               0.333333
# 324                     33               0.461538               0.358974
# 325                     34               0.439024               0.342105
# 326                     35               0.390244               0.375000
# 327                     25               0.470588               0.333333
#
#      split2_test_precision  split3_test_precision  split4_test_precision  \
# 0                 0.000000               0.000000               0.000000
# 1                 0.000000               0.000000               0.000000
# 2                 0.000000               0.000000               0.000000
# 3                 0.000000               0.000000               0.000000
# 4                 0.000000               0.000000               0.333333
# ..                     ...                    ...                    ...
# 323               0.468750               0.463415               0.382353
# 324               0.515152               0.452381               0.378378
# 325               0.484848               0.476190               0.371429
# 326               0.500000               0.452381               0.352941
# 327               0.500000               0.463415               0.371429
#
#      mean_test_precision  std_test_precision  rank_test_precision  \
# 0               0.200000            0.400000                   34
# 1               0.200000            0.400000                   34
# 2               0.200000            0.400000                   34
# 3               0.200000            0.400000                   34
# 4               0.266667            0.388730                   32
# ..                   ...                 ...                  ...
# 323             0.419044            0.052791                   36
# 324             0.433285            0.057275                   25
# 325             0.422719            0.056770                   35
# 326             0.414113            0.054190                   39
# 327             0.427753            0.063896                   28
#
#      split0_test_NPV  split1_test_NPV  split2_test_NPV  split3_test_NPV  \
# 0           0.775510         0.808511         0.770833         0.770833
# 1           0.775510         0.808511         0.770833         0.770833
# 2           0.775510         0.808511         0.770833         0.770833
# 3           0.775510         0.808511         0.770833         0.770833
# 4           0.770833         0.808511         0.770833         0.770833
# ..               ...              ...              ...              ...
# 323         0.733333         0.684783         0.729167         0.747126
# 324         0.741573         0.696629         0.747368         0.744186
# 325         0.735632         0.688889         0.736842         0.755814
# 326         0.712644         0.704545         0.739583         0.744186
# 327         0.734043         0.686047         0.739583         0.747126
#
#      split4_test_NPV  mean_test_NPV  std_test_NPV  rank_test_NPV  \
# 0           0.770833       0.779304      0.014715             33
# 1           0.770833       0.779304      0.014715             33
# 2           0.770833       0.779304      0.014715             33
# 3           0.770833       0.779304      0.014715             33
# 4           0.777778       0.779758      0.014626             32
# ..               ...            ...           ...            ...
# 323         0.702128       0.719307      0.022605             30
# 324         0.703297       0.726611      0.021937             12
# 325         0.698925       0.723220      0.025183             21
# 326         0.691489       0.718490      0.020312             31
# 327         0.698925       0.721145      0.024112             24
#
#      split0_test_PPV  split1_test_PPV  split2_test_PPV  split3_test_PPV  \
# 0           0.000000         1.000000         0.000000         0.000000
# 1           0.000000         1.000000         0.000000         0.000000
# 2           0.000000         1.000000         0.000000         0.000000
# 3           0.000000         1.000000         0.000000         0.000000
# 4           0.000000         1.000000         0.000000         0.000000
# ..               ...              ...              ...              ...
# 323         0.447368         0.333333         0.468750         0.463415
# 324         0.461538         0.358974         0.515152         0.452381
# 325         0.439024         0.342105         0.484848         0.476190
# 326         0.390244         0.375000         0.500000         0.452381
# 327         0.470588         0.333333         0.500000         0.463415
#
#      split4_test_PPV  mean_test_PPV  std_test_PPV  rank_test_PPV  cv  \
# 0           0.000000       0.200000      0.400000             34   5
# 1           0.000000       0.200000      0.400000             34   5
# 2           0.000000       0.200000      0.400000             34   5
# 3           0.000000       0.200000      0.400000             34   5
# 4           0.333333       0.266667      0.388730             32   5
# ..               ...            ...           ...            ...  ..
# 323         0.382353       0.419044      0.052791             36   5
# 324         0.378378       0.433285      0.057275             25   5
# 325         0.371429       0.422719      0.056770             35   5
# 326         0.352941       0.414113      0.054190             39   5
# 327         0.371429       0.427753      0.063896             28   5
#
#                               Title     RunType          MainDataset  \
# 0        dfcmpltPreLC_SITE5_Holdout     Holdout   dfcmpltPreLC_SITE5
# 1        dfcmpltPreLC_SITE5_Holdout     Holdout   dfcmpltPreLC_SITE5
# 2        dfcmpltPreLC_SITE5_Holdout     Holdout   dfcmpltPreLC_SITE5
# 3        dfcmpltPreLC_SITE5_Holdout     Holdout   dfcmpltPreLC_SITE5
# 4        dfcmpltPreLC_SITE5_Holdout     Holdout   dfcmpltPreLC_SITE5
# ..                              ...         ...                  ...
# 323  dfcmpltPreLC2_SITE6_Boruta_Top  Boruta_Top  dfcmpltPreLC2_SITE6
# 324  dfcmpltPreLC2_SITE6_Boruta_Top  Boruta_Top  dfcmpltPreLC2_SITE6
# 325  dfcmpltPreLC2_SITE6_Boruta_Top  Boruta_Top  dfcmpltPreLC2_SITE6
# 326  dfcmpltPreLC2_SITE6_Boruta_Top  Boruta_Top  dfcmpltPreLC2_SITE6
# 327  dfcmpltPreLC2_SITE6_Boruta_Top  Boruta_Top  dfcmpltPreLC2_SITE6
#
#                                                   date classifier FeatureSet  \
# 0    <built-in method today of type object at 0x7ad...        NaN        NaN
# 1    <built-in method today of type object at 0x7ad...        NaN        NaN
# 2    <built-in method today of type object at 0x7ad...        NaN        NaN
# 3    <built-in method today of type object at 0x7ad...        NaN        NaN
# 4    <built-in method today of type object at 0x7ad...        NaN        NaN
# ..                                                 ...        ...        ...
# 323                         2024-05-01 21:34:03.895196        NaN        NaN
# 324                         2024-05-01 21:34:03.895196        NaN        NaN
# 325                         2024-05-01 21:34:03.895196        NaN        NaN
# 326                         2024-05-01 21:34:03.895196        NaN        NaN
# 327                         2024-05-01 21:34:03.895196        NaN        NaN
#
#      brt_nTrue  brt_nTop  brt_md                 brt_params
# 0          NaN       NaN     NaN                        NaN
# 1          NaN       NaN     NaN                        NaN
# 2          NaN       NaN     NaN                        NaN
# 3          NaN       NaN     NaN                        NaN
# 4          NaN       NaN     NaN                        NaN
# ..         ...       ...     ...                        ...
# 323        2.0       6.0     7.0  T1000_itrr500_th100_topR5
# 324        2.0       6.0     7.0  T1000_itrr500_th100_topR5
# 325        2.0       6.0     7.0  T1000_itrr500_th100_topR5
# 326        2.0       6.0     7.0  T1000_itrr500_th100_topR5
# 327        2.0       6.0     7.0  T1000_itrr500_th100_topR5
#
# [17381 rows x 102 columns]

# %%
dfRes["classifier"] = dfRes["param_clf"].apply(lambda x: x.__str__().split("(")[0])
dfRes['site'] = dfRes['MainDataset'].apply(changeSite)
lColFirst = [
    "MainDataset",
    "Title",
    'site',
    "date",
    "classifier",
    'RunType',
    "cv",
    'FeatureSet',
    "brt_nTrue",
    "brt_nTop",
    'brt_md',
]
dfRes = MPutils.reorder_columns(dfRes, lColFirst)
dfRes.to_csv("OUTPUT/MP/05-classifiers/DataV3/CLFRunCombined.csv", index=False)
dfResOrg = deepcopy(dfRes)
lColsSel = lColFirst + [
    x
    for x in dfRes
    if (x.startswith("mean_test") or x.startswith("param_") or x.startswith("brt_"))
    and x not in lColFirst
]
dfRes[lColsSel].to_csv("OUTPUT/MP/05-classifiers/DataV3/CLFRunCombined_SelCol.csv")

# %% [markdown]
# # Go through Data and Simplify for inspection

# %%
dfRes = dfRes[lColsSel]

# %%
dfRes
# Out:
#              MainDataset                           Title    site  \
# 0     dfcmpltPreLC_SITE5      dfcmpltPreLC_SITE5_Holdout     LUS
# 1     dfcmpltPreLC_SITE5      dfcmpltPreLC_SITE5_Holdout     LUS
# 2     dfcmpltPreLC_SITE5      dfcmpltPreLC_SITE5_Holdout     LUS
# 3     dfcmpltPreLC_SITE5      dfcmpltPreLC_SITE5_Holdout     LUS
# 4     dfcmpltPreLC_SITE5      dfcmpltPreLC_SITE5_Holdout     LUS
# ..                   ...                             ...     ...
# 323  dfcmpltPreLC2_SITE6  dfcmpltPreLC2_SITE6_Boruta_Top  Canada
# 324  dfcmpltPreLC2_SITE6  dfcmpltPreLC2_SITE6_Boruta_Top  Canada
# 325  dfcmpltPreLC2_SITE6  dfcmpltPreLC2_SITE6_Boruta_Top  Canada
# 326  dfcmpltPreLC2_SITE6  dfcmpltPreLC2_SITE6_Boruta_Top  Canada
# 327  dfcmpltPreLC2_SITE6  dfcmpltPreLC2_SITE6_Boruta_Top  Canada
#
#                                                   date  \
# 0    <built-in method today of type object at 0x7ad...
# 1    <built-in method today of type object at 0x7ad...
# 2    <built-in method today of type object at 0x7ad...
# 3    <built-in method today of type object at 0x7ad...
# 4    <built-in method today of type object at 0x7ad...
# ..                                                 ...
# 323                         2024-05-01 21:34:03.895196
# 324                         2024-05-01 21:34:03.895196
# 325                         2024-05-01 21:34:03.895196
# 326                         2024-05-01 21:34:03.895196
# 327                         2024-05-01 21:34:03.895196
#
#                  classifier     RunType  cv FeatureSet  brt_nTrue  brt_nTop  \
# 0    RandomForestClassifier     Holdout   5        NaN        NaN       NaN
# 1    RandomForestClassifier     Holdout   5        NaN        NaN       NaN
# 2    RandomForestClassifier     Holdout   5        NaN        NaN       NaN
# 3    RandomForestClassifier     Holdout   5        NaN        NaN       NaN
# 4    RandomForestClassifier     Holdout   5        NaN        NaN       NaN
# ..                      ...         ...  ..        ...        ...       ...
# 323           XGBClassifier  Boruta_Top   5        NaN        2.0       6.0
# 324           XGBClassifier  Boruta_Top   5        NaN        2.0       6.0
# 325           XGBClassifier  Boruta_Top   5        NaN        2.0       6.0
# 326           XGBClassifier  Boruta_Top   5        NaN        2.0       6.0
# 327           XGBClassifier  Boruta_Top   5        NaN        2.0       6.0
#
#      brt_md                                          param_clf  \
# 0       NaN                           RandomForestClassifier()
# 1       NaN                           RandomForestClassifier()
# 2       NaN                           RandomForestClassifier()
# 3       NaN                           RandomForestClassifier()
# 4       NaN                           RandomForestClassifier()
# ..      ...                                                ...
# 323     7.0  XGBClassifier(base_score=None, booster=None, c...
# 324     7.0  XGBClassifier(base_score=None, booster=None, c...
# 325     7.0  XGBClassifier(base_score=None, booster=None, c...
# 326     7.0  XGBClassifier(base_score=None, booster=None, c...
# 327     7.0  XGBClassifier(base_score=None, booster=None, c...
#
#      param_clf__max_depth  param_clf__n_estimators  param_clf__random_state  \
# 0                     3.0                    100.0                     42.0
# 1                     3.0                   1000.0                     42.0
# 2                     6.0                    100.0                     42.0
# 3                     6.0                   1000.0                     42.0
# 4                    10.0                    100.0                     42.0
# ..                    ...                      ...                      ...
# 323                  10.0                   1000.0                     42.0
# 324                  15.0                    100.0                     42.0
# 325                  15.0                   1000.0                     42.0
# 326                   NaN                    100.0                     42.0
# 327                   NaN                   1000.0                     42.0
#
#      param_clf__max_iter  param_clf__learning_rate  mean_test_accuracy  \
# 0                    NaN                       NaN            0.780102
# 1                    NaN                       NaN            0.780102
# 2                    NaN                       NaN            0.780102
# 3                    NaN                       NaN            0.780102
# 4                    NaN                       NaN            0.771854
# ..                   ...                       ...                 ...
# 323                  NaN                       1.0            0.634375
# 324                  NaN                       1.0            0.639062
# 325                  NaN                       1.0            0.634375
# 326                  NaN                       1.0            0.628125
# 327                  NaN                       1.0            0.635938
#
#      mean_test_balanced_accuracy  mean_test_roc_auc  mean_test_f1  \
# 0                       0.510000           0.692749      0.036364
# 1                       0.510000           0.693193      0.036364
# 2                       0.510000           0.652312      0.036364
# 3                       0.510000           0.674936      0.036364
# 4                       0.511054           0.677128      0.064935
# ..                           ...                ...           ...
# 323                     0.564676           0.603757      0.392622
# 324                     0.575862           0.606672      0.415253
# 325                     0.569835           0.600561      0.404921
# 326                     0.562658           0.612700      0.395360
# 327                     0.568405           0.603084      0.401578
#
#      mean_test_recall  mean_test_sensitivity  mean_test_specificity  \
# 0            0.020000               0.020000               1.000000
# 1            0.020000               0.020000               1.000000
# 2            0.020000               0.020000               1.000000
# 3            0.020000               0.020000               1.000000
# 4            0.038182               0.038182               0.983926
# ..                ...                    ...                    ...
# 323          0.370732               0.370732               0.758621
# 324          0.400000               0.400000               0.751724
# 325          0.390244               0.390244               0.749425
# 326          0.380488               0.380488               0.744828
# 327          0.380488               0.380488               0.756322
#
#      mean_test_precision  mean_test_NPV  mean_test_PPV  \
# 0               0.200000       0.779304       0.200000
# 1               0.200000       0.779304       0.200000
# 2               0.200000       0.779304       0.200000
# 3               0.200000       0.779304       0.200000
# 4               0.266667       0.779758       0.266667
# ..                   ...            ...            ...
# 323             0.419044       0.719307       0.419044
# 324             0.433285       0.726611       0.433285
# 325             0.422719       0.723220       0.422719
# 326             0.414113       0.718490       0.414113
# 327             0.427753       0.721145       0.427753
#
#                     brt_params
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 323  T1000_itrr500_th100_topR5
# 324  T1000_itrr500_th100_topR5
# 325  T1000_itrr500_th100_topR5
# 326  T1000_itrr500_th100_topR5
# 327  T1000_itrr500_th100_topR5
#
# [17381 rows x 28 columns]

# %%
lSelMainData = [
"dfcmpltPreLC4",
"dfcmpltPreLC4_SITE1",
"dfcmpltPreLC4_SITE2",
"dfcmpltPreLC4_SITE3",
"dfcmpltPreLC4_SITE4",
"dfcmpltPreLC4_SITE5",
"dfcmpltPreLC4_SITE6",
"dfcmpltPreLC4_SITE7",
]

lPrettyCols =     [
        "MainDataset",
        "RunType",
        "classifier",
        "brt_nTrue",
        "brt_nTop",
        "accuracy",
        "balanced_accuracy",
        "roc_auc",
        "f1",
        "recall",
        "sensitivity",
        "specificity",
        "precision",
        "NPV",
        "PPV",
        "brt_md",
        'brt_params'
    ]
lPrettyColsSite = [
    "MainDataset",
    "RunType",
    'site',
    "classifier",
    "accuracy",
    "balanced_accuracy",
    "roc_auc",
    "f1",
    "recall",
    "sensitivity",
    "specificity",
    "precision",
    "NPV",
    "PPV",
]
s_brt = 'and (RunType=="Boruta_True" or RunType=="Boruta_Top")'
s_RF10 = 'classifier=="RandomForestClassifier" and param_clf__n_estimators==1000 and param_clf__max_depth==10'
s_RFXGB10 = 'param_clf__n_estimators==1000 and param_clf__max_depth==10'
s_CMPLT = 'MainDataset=="dfcmpltPreLC4"'
s_val = 'RunType=="HoldoutVal"'

# %%
dfRes = dfRes[dfRes['MainDataset'].isin(lSelMainData)]
dfRes.columns = [x.replace('mean_test_','') for x in dfRes.columns]

# %% [markdown]
# # Inspect Original Holdout
# - May have duplicates

# %%
dfRes.query(f'{s_RF10} and RunType=="Holdout"').sort_values("balanced_accuracy", ascending=False)[lPrettyColsSite].T
# Out:
#                                         5                       5  \
# MainDataset           dfcmpltPreLC4_SITE4     dfcmpltPreLC4_SITE4
# RunType                           Holdout                 Holdout
# site                                  RIO                     RIO
# classifier         RandomForestClassifier  RandomForestClassifier
# accuracy                              1.0                     1.0
# balanced_accuracy                     1.0                     1.0
# roc_auc                               1.0                     1.0
# f1                                    1.0                     1.0
# recall                                1.0                     1.0
# sensitivity                           1.0                     1.0
# specificity                           1.0                     1.0
# precision                             1.0                     1.0
# NPV                                   1.0                     1.0
# PPV                                   1.0                     1.0
#
#                                         5                       5  \
# MainDataset           dfcmpltPreLC4_SITE1     dfcmpltPreLC4_SITE1
# RunType                           Holdout                 Holdout
# site                                  LDN                     LDN
# classifier         RandomForestClassifier  RandomForestClassifier
# accuracy                         0.912121                0.912121
# balanced_accuracy                0.912143                0.912143
# roc_auc                          0.952857                0.952857
# f1                               0.892929                0.892929
# recall                               0.91                    0.91
# sensitivity                          0.91                    0.91
# specificity                      0.914286                0.914286
# precision                        0.886667                0.886667
# NPV                              0.941667                0.941667
# PPV                              0.886667                0.886667
#
#                                         5                       5  \
# MainDataset           dfcmpltPreLC4_SITE3     dfcmpltPreLC4_SITE3
# RunType                           Holdout                 Holdout
# site                                  SAN                     SAN
# classifier         RandomForestClassifier  RandomForestClassifier
# accuracy                         0.865934                0.865934
# balanced_accuracy                0.826061                0.826061
# roc_auc                          0.904242                0.904242
# f1                               0.911104                0.911104
# recall                           0.885455                0.885455
# sensitivity                      0.885455                0.885455
# specificity                      0.766667                0.766667
# precision                        0.941111                0.941111
# NPV                                   0.7                     0.7
# PPV                              0.941111                0.941111
#
#                                         5                       5  \
# MainDataset                 dfcmpltPreLC4           dfcmpltPreLC4
# RunType                           Holdout                 Holdout
# site                               Global                  Global
# classifier         RandomForestClassifier  RandomForestClassifier
# accuracy                          0.71582                 0.71582
# balanced_accuracy                0.658054                0.658054
# roc_auc                          0.773869                0.773869
# f1                               0.511843                0.511843
# recall                           0.375131                0.375131
# sensitivity                      0.375131                0.375131
# specificity                      0.940977                0.940977
# precision                        0.811677                0.811677
# NPV                              0.695027                0.695027
# PPV                              0.811677                0.811677
#
#                                         5                       5  \
# MainDataset           dfcmpltPreLC4_SITE7     dfcmpltPreLC4_SITE7
# RunType                           Holdout                 Holdout
# site                         NorthAmerica            NorthAmerica
# classifier         RandomForestClassifier  RandomForestClassifier
# accuracy                         0.721814                0.721814
# balanced_accuracy                0.625205                0.625205
# roc_auc                          0.769748                0.769748
# f1                               0.414798                0.414798
# recall                           0.277176                0.277176
# sensitivity                      0.277176                0.277176
# specificity                      0.973233                0.973233
# precision                        0.854393                0.854393
# NPV                              0.704851                0.704851
# PPV                              0.854393                0.854393
#
#                                         5                       5  \
# MainDataset           dfcmpltPreLC4_SITE6     dfcmpltPreLC4_SITE6
# RunType                           Holdout                 Holdout
# site                               Canada                  Canada
# classifier         RandomForestClassifier  RandomForestClassifier
# accuracy                         0.708149                0.708149
# balanced_accuracy                0.556341                0.556341
# roc_auc                          0.723729                0.723729
# f1                               0.238184                0.238184
# recall                              0.145                   0.145
# sensitivity                         0.145                   0.145
# specificity                      0.967682                0.967682
# precision                        0.699206                0.699206
# NPV                               0.71062                 0.71062
# PPV                              0.699206                0.699206
#
#                                         5                       5  \
# MainDataset           dfcmpltPreLC4_SITE2     dfcmpltPreLC4_SITE2
# RunType                           Holdout                 Holdout
# site                                  MTL                     MTL
# classifier         RandomForestClassifier  RandomForestClassifier
# accuracy                         0.694963                0.694963
# balanced_accuracy                 0.52096                 0.52096
# roc_auc                          0.676959                0.676959
# f1                               0.118133                0.118133
# recall                           0.066984                0.066984
# sensitivity                      0.066984                0.066984
# specificity                      0.974937                0.974937
# precision                        0.592857                0.592857
# NPV                              0.700906                0.700906
# PPV                              0.592857                0.592857
#
#                                         5                       5
# MainDataset           dfcmpltPreLC4_SITE5     dfcmpltPreLC4_SITE5
# RunType                           Holdout                 Holdout
# site                                  LUS                     LUS
# classifier         RandomForestClassifier  RandomForestClassifier
# accuracy                          0.77602                 0.77602
# balanced_accuracy                0.507368                0.507368
# roc_auc                          0.673141                0.673141
# f1                               0.036364                0.036364
# recall                               0.02                    0.02
# sensitivity                          0.02                    0.02
# specificity                      0.994737                0.994737
# precision                             0.2                     0.2
# NPV                              0.778369                0.778369
# PPV                                   0.2                     0.2

# %% [markdown]
# # Per site - Best Results

# %%
dfRes.query(f'{s_RF10} and RunType=="Boruta_True"').sort_values('balanced_accuracy',ascending=False)
# Out:
#              MainDataset                            Title          site  \
# 87   dfcmpltPreLC4_SITE4  dfcmpltPreLC4_SITE4_Boruta_True           RIO
# 251  dfcmpltPreLC4_SITE4  dfcmpltPreLC4_SITE4_Boruta_True           RIO
# 169  dfcmpltPreLC4_SITE4  dfcmpltPreLC4_SITE4_Boruta_True           RIO
# 251  dfcmpltPreLC4_SITE3  dfcmpltPreLC4_SITE3_Boruta_True           SAN
# 169  dfcmpltPreLC4_SITE3  dfcmpltPreLC4_SITE3_Boruta_True           SAN
# 87   dfcmpltPreLC4_SITE3  dfcmpltPreLC4_SITE3_Boruta_True           SAN
# 87   dfcmpltPreLC4_SITE1  dfcmpltPreLC4_SITE1_Boruta_True           LDN
# 169  dfcmpltPreLC4_SITE1  dfcmpltPreLC4_SITE1_Boruta_True           LDN
# 251  dfcmpltPreLC4_SITE1  dfcmpltPreLC4_SITE1_Boruta_True           LDN
# 87         dfcmpltPreLC4        dfcmpltPreLC4_Boruta_True        Global
# 87   dfcmpltPreLC4_SITE7  dfcmpltPreLC4_SITE7_Boruta_True  NorthAmerica
# 169        dfcmpltPreLC4        dfcmpltPreLC4_Boruta_True        Global
# 169  dfcmpltPreLC4_SITE7  dfcmpltPreLC4_SITE7_Boruta_True  NorthAmerica
# 251  dfcmpltPreLC4_SITE7  dfcmpltPreLC4_SITE7_Boruta_True  NorthAmerica
# 87   dfcmpltPreLC4_SITE6  dfcmpltPreLC4_SITE6_Boruta_True        Canada
# 87   dfcmpltPreLC4_SITE2  dfcmpltPreLC4_SITE2_Boruta_True           MTL
# 169  dfcmpltPreLC4_SITE6  dfcmpltPreLC4_SITE6_Boruta_True        Canada
# 251  dfcmpltPreLC4_SITE6  dfcmpltPreLC4_SITE6_Boruta_True        Canada
# 169  dfcmpltPreLC4_SITE2  dfcmpltPreLC4_SITE2_Boruta_True           MTL
# 251  dfcmpltPreLC4_SITE2  dfcmpltPreLC4_SITE2_Boruta_True           MTL
# 251        dfcmpltPreLC4        dfcmpltPreLC4_Boruta_True        Global
# 169  dfcmpltPreLC4_SITE5  dfcmpltPreLC4_SITE5_Boruta_True           LUS
# 251  dfcmpltPreLC4_SITE5  dfcmpltPreLC4_SITE5_Boruta_True           LUS
# 87   dfcmpltPreLC4_SITE5  dfcmpltPreLC4_SITE5_Boruta_True           LUS
#
#                            date              classifier      RunType  cv  \
# 87   2024-05-06 10:48:45.301840  RandomForestClassifier  Boruta_True   5
# 251  2024-05-06 10:48:45.301840  RandomForestClassifier  Boruta_True   5
# 169  2024-05-06 10:48:45.301840  RandomForestClassifier  Boruta_True   5
# 251  2024-05-06 10:41:21.307882  RandomForestClassifier  Boruta_True   5
# 169  2024-05-06 10:41:21.307882  RandomForestClassifier  Boruta_True   5
# 87   2024-05-06 10:41:21.307882  RandomForestClassifier  Boruta_True   5
# 87   2024-05-06 10:20:07.740764  RandomForestClassifier  Boruta_True   5
# 169  2024-05-06 10:20:07.740764  RandomForestClassifier  Boruta_True   5
# 251  2024-05-06 10:20:07.740764  RandomForestClassifier  Boruta_True   5
# 87   2024-05-06 10:08:36.667108  RandomForestClassifier  Boruta_True   5
# 87   2024-05-06 11:20:32.414037  RandomForestClassifier  Boruta_True   5
# 169  2024-05-06 10:08:36.667108  RandomForestClassifier  Boruta_True   5
# 169  2024-05-06 11:20:32.414037  RandomForestClassifier  Boruta_True   5
# 251  2024-05-06 11:20:32.414037  RandomForestClassifier  Boruta_True   5
# 87   2024-05-06 11:06:12.352062  RandomForestClassifier  Boruta_True   5
# 87   2024-05-06 10:33:25.263667  RandomForestClassifier  Boruta_True   5
# 169  2024-05-06 11:06:12.352062  RandomForestClassifier  Boruta_True   5
# 251  2024-05-06 11:06:12.352062  RandomForestClassifier  Boruta_True   5
# 169  2024-05-06 10:33:25.263667  RandomForestClassifier  Boruta_True   5
# 251  2024-05-06 10:33:25.263667  RandomForestClassifier  Boruta_True   5
# 251  2024-05-06 10:08:36.667108  RandomForestClassifier  Boruta_True   5
# 169  2024-05-06 10:52:53.833479  RandomForestClassifier  Boruta_True   5
# 251  2024-05-06 10:52:53.833479  RandomForestClassifier  Boruta_True   5
# 87   2024-05-06 10:52:53.833479  RandomForestClassifier  Boruta_True   5
#
#     FeatureSet  brt_nTrue  brt_nTop  brt_md                 param_clf  \
# 87         NaN       19.0      23.0     3.0  RandomForestClassifier()
# 251        NaN       11.0      16.0     7.0  RandomForestClassifier()
# 169        NaN       11.0      15.0     5.0  RandomForestClassifier()
# 251        NaN        3.0       7.0     7.0  RandomForestClassifier()
# 169        NaN        5.0       9.0     5.0  RandomForestClassifier()
# 87         NaN       13.0      17.0     3.0  RandomForestClassifier()
# 87         NaN       15.0      19.0     3.0  RandomForestClassifier()
# 169        NaN        6.0      10.0     5.0  RandomForestClassifier()
# 251        NaN        6.0      10.0     7.0  RandomForestClassifier()
# 87         NaN       21.0      26.0     3.0  RandomForestClassifier()
# 87         NaN       18.0      23.0     3.0  RandomForestClassifier()
# 169        NaN       11.0      15.0     5.0  RandomForestClassifier()
# 169        NaN        9.0      13.0     5.0  RandomForestClassifier()
# 251        NaN        3.0       8.0     7.0  RandomForestClassifier()
# 87         NaN       14.0      18.0     3.0  RandomForestClassifier()
# 87         NaN       10.0      14.0     3.0  RandomForestClassifier()
# 169        NaN        4.0       8.0     5.0  RandomForestClassifier()
# 251        NaN        2.0       6.0     7.0  RandomForestClassifier()
# 169        NaN        3.0       7.0     5.0  RandomForestClassifier()
# 251        NaN        2.0       6.0     7.0  RandomForestClassifier()
# 251        NaN        3.0       7.0     7.0  RandomForestClassifier()
# 169        NaN        2.0       6.0     5.0  RandomForestClassifier()
# 251        NaN        1.0       5.0     7.0  RandomForestClassifier()
# 87         NaN        3.0       7.0     3.0  RandomForestClassifier()
#
#      param_clf__max_depth  param_clf__n_estimators  param_clf__random_state  \
# 87                   10.0                   1000.0                     42.0
# 251                  10.0                   1000.0                     42.0
# 169                  10.0                   1000.0                     42.0
# 251                  10.0                   1000.0                     42.0
# 169                  10.0                   1000.0                     42.0
# 87                   10.0                   1000.0                     42.0
# 87                   10.0                   1000.0                     42.0
# 169                  10.0                   1000.0                     42.0
# 251                  10.0                   1000.0                     42.0
# 87                   10.0                   1000.0                     42.0
# 87                   10.0                   1000.0                     42.0
# 169                  10.0                   1000.0                     42.0
# 169                  10.0                   1000.0                     42.0
# 251                  10.0                   1000.0                     42.0
# 87                   10.0                   1000.0                     42.0
# 87                   10.0                   1000.0                     42.0
# 169                  10.0                   1000.0                     42.0
# 251                  10.0                   1000.0                     42.0
# 169                  10.0                   1000.0                     42.0
# 251                  10.0                   1000.0                     42.0
# 251                  10.0                   1000.0                     42.0
# 169                  10.0                   1000.0                     42.0
# 251                  10.0                   1000.0                     42.0
# 87                   10.0                   1000.0                     42.0
#
#      param_clf__max_iter  param_clf__learning_rate  accuracy  \
# 87                   NaN                       NaN  0.981048
# 251                  NaN                       NaN  0.981048
# 169                  NaN                       NaN  0.981048
# 251                  NaN                       NaN  0.926374
# 169                  NaN                       NaN  0.910989
# 87                   NaN                       NaN  0.910989
# 87                   NaN                       NaN  0.804545
# 169                  NaN                       NaN  0.768182
# 251                  NaN                       NaN  0.768182
# 87                   NaN                       NaN  0.688497
# 87                   NaN                       NaN  0.697538
# 169                  NaN                       NaN  0.652080
# 169                  NaN                       NaN  0.674691
# 251                  NaN                       NaN  0.666221
# 87                   NaN                       NaN  0.698725
# 87                   NaN                       NaN  0.688096
# 169                  NaN                       NaN  0.651344
# 251                  NaN                       NaN  0.648206
# 169                  NaN                       NaN  0.642969
# 251                  NaN                       NaN  0.648171
# 251                  NaN                       NaN  0.581063
# 169                  NaN                       NaN  0.717602
# 251                  NaN                       NaN  0.701105
# 87                   NaN                       NaN  0.672449
#
#      balanced_accuracy   roc_auc        f1    recall  sensitivity  \
# 87            0.946667  0.998462  0.988819  1.000000     1.000000
# 251           0.946667  0.996923  0.988819  1.000000     1.000000
# 169           0.946667  0.996923  0.988819  1.000000     1.000000
# 251           0.929394  0.956061  0.950426  0.925455     0.925455
# 169           0.855152  0.963030  0.942733  0.943636     0.943636
# 87            0.855152  0.950909  0.942733  0.943636     0.943636
# 87            0.788571  0.880000  0.743492  0.720000     0.720000
# 169           0.770714  0.881429  0.736580  0.770000     0.770000
# 251           0.770714  0.881429  0.736580  0.770000     0.770000
# 87            0.638307  0.734955  0.501326  0.394488     0.394488
# 87            0.631497  0.751774  0.485046  0.396627     0.396627
# 169           0.622142  0.692515  0.520314  0.476933     0.476933
# 169           0.620732  0.690659  0.487352  0.428706     0.428706
# 251           0.615895  0.686167  0.483196  0.436784     0.436784
# 87            0.597880  0.687070  0.406034  0.326795     0.326795
# 87            0.592381  0.666842  0.400498  0.344762     0.344762
# 169           0.560376  0.599962  0.362539  0.316154     0.316154
# 251           0.555248  0.602217  0.351019  0.305897     0.305897
# 169           0.550238  0.592340  0.344892  0.310476     0.310476
# 251           0.544345  0.594440  0.322123  0.276190     0.276190
# 251           0.544072  0.579743  0.406994  0.364551     0.364551
# 169           0.488213  0.419454  0.102991  0.072727     0.072727
# 251           0.484628  0.448674  0.115693  0.092727     0.092727
# 87            0.484605  0.549123  0.160381  0.145455     0.145455
#
#      specificity  precision       NPV       PPV                 brt_params
# 87      0.893333   0.978307  1.000000  0.978307  T1000_itrr500_th100_topR5
# 251     0.893333   0.978307  1.000000  0.978307  T1000_itrr500_th100_topR5
# 169     0.893333   0.978307  1.000000  0.978307  T1000_itrr500_th100_topR5
# 251     0.933333   0.981818  0.820000  0.981818  T1000_itrr500_th100_topR5
# 169     0.766667   0.943333  0.833333  0.943333  T1000_itrr500_th100_topR5
# 87      0.766667   0.943333  0.833333  0.943333  T1000_itrr500_th100_topR5
# 87      0.857143   0.793333  0.831429  0.793333  T1000_itrr500_th100_topR5
# 169     0.771429   0.761667  0.830556  0.761667  T1000_itrr500_th100_topR5
# 251     0.771429   0.761667  0.830556  0.761667  T1000_itrr500_th100_topR5
# 87      0.882126   0.691237  0.688649  0.691237  T1000_itrr500_th100_topR5
# 87      0.866367   0.626783  0.719036  0.626783  T1000_itrr500_th100_topR5
# 169     0.767350   0.573788  0.690644  0.573788  T1000_itrr500_th100_topR5
# 169     0.812759   0.566064  0.716693  0.566064  T1000_itrr500_th100_topR5
# 251     0.795006   0.548038  0.715991  0.548038  T1000_itrr500_th100_topR5
# 87      0.868966   0.540606  0.738110  0.540606  T1000_itrr500_th100_topR5
# 87      0.840000   0.480362  0.744137  0.480362  T1000_itrr500_th100_topR5
# 169     0.804598   0.425035  0.720165  0.425035  T1000_itrr500_th100_topR5
# 251     0.804598   0.420627  0.717311  0.420627  T1000_itrr500_th100_topR5
# 169     0.790000   0.392015  0.722051  0.392015  T1000_itrr500_th100_topR5
# 251     0.812500   0.389798  0.717777  0.389798  T1000_itrr500_th100_topR5
# 251     0.723593   0.464663  0.633934  0.464663  T1000_itrr500_th100_topR5
# 169     0.903698   0.208571  0.771361  0.208571  T1000_itrr500_th100_topR5
# 251     0.876529   0.155476  0.769810  0.155476  T1000_itrr500_th100_topR5
# 87      0.823755   0.192879  0.769736  0.192879  T1000_itrr500_th100_topR5

# %%
# dfTmp = dfRes.query(f'{s_RF10} and RunType=="Boruta_True"').sort_values('balanced_accuracy',ascending=False)
dfTmp = dfRes.query(f'RunType=="Boruta_True" and {s_RFXGB10}').sort_values('balanced_accuracy',ascending=False)

lTopBrt = []
for i in lSelMainData:
    dfTmpTop = dfTmp.query(f'MainDataset=="{i}"').sort_values('balanced_accuracy',ascending=False)
    lTopBrt.append(dfTmpTop.iloc[0,:])

# %%
pd.DataFrame(lTopBrt)[lPrettyColsSite+['brt_md','brt_nTrue','Title']].sort_values('balanced_accuracy',ascending=False)
# Out:
#              MainDataset      RunType          site              classifier  \
# 108  dfcmpltPreLC4_SITE4  Boruta_True           RIO           XGBClassifier
# 251  dfcmpltPreLC4_SITE3  Boruta_True           SAN  RandomForestClassifier
# 180  dfcmpltPreLC4_SITE1  Boruta_True           LDN           XGBClassifier
# 98   dfcmpltPreLC4_SITE7  Boruta_True  NorthAmerica           XGBClassifier
# 87         dfcmpltPreLC4  Boruta_True        Global  RandomForestClassifier
# 108  dfcmpltPreLC4_SITE2  Boruta_True           MTL           XGBClassifier
# 118  dfcmpltPreLC4_SITE6  Boruta_True        Canada           XGBClassifier
# 169  dfcmpltPreLC4_SITE5  Boruta_True           LUS  RandomForestClassifier
#
#      accuracy  balanced_accuracy   roc_auc        f1    recall  sensitivity  \
# 108  0.987298           0.963333  0.997436  0.992453  1.000000     1.000000
# 251  0.926374           0.929394  0.956061  0.950426  0.925455     0.925455
# 180  0.822727           0.824286  0.898571  0.786580  0.820000     0.820000
# 98   0.670436           0.639128  0.665584  0.535374  0.527843     0.527843
# 87   0.688497           0.638307  0.734955  0.501326  0.394488     0.394488
# 108  0.672489           0.607897  0.613859  0.453217  0.440794     0.440794
# 118  0.656205           0.598358  0.617495  0.445285  0.442692     0.442692
# 169  0.717602           0.488213  0.419454  0.102991  0.072727     0.072727
#
#      specificity  precision       NPV       PPV  brt_md  brt_nTrue  \
# 108     0.926667   0.985185  1.000000  0.985185     3.0       19.0
# 251     0.933333   0.981818  0.820000  0.981818     7.0        3.0
# 180     0.828571   0.816667  0.901984  0.816667     5.0        6.0
# 98      0.750412   0.545507  0.738903  0.545507     3.0       18.0
# 87      0.882126   0.691237  0.688649  0.691237     3.0       21.0
# 108     0.775000   0.468233  0.757557  0.468233     3.0       10.0
# 118     0.754023   0.450340  0.747817  0.450340     3.0       14.0
# 169     0.903698   0.208571  0.771361  0.208571     5.0        2.0
#
#                                Title
# 108  dfcmpltPreLC4_SITE4_Boruta_True
# 251  dfcmpltPreLC4_SITE3_Boruta_True
# 180  dfcmpltPreLC4_SITE1_Boruta_True
# 98   dfcmpltPreLC4_SITE7_Boruta_True
# 87         dfcmpltPreLC4_Boruta_True
# 108  dfcmpltPreLC4_SITE2_Boruta_True
# 118  dfcmpltPreLC4_SITE6_Boruta_True
# 169  dfcmpltPreLC4_SITE5_Boruta_True

# %%
pd.DataFrame(lTopBrt)[['brt_md','brt_nTrue','Title']+lPrettyColsSite].sort_values('MainDataset',ascending=True)
# Out:
#      brt_md  brt_nTrue                            Title          MainDataset  \
# 87      3.0       21.0        dfcmpltPreLC4_Boruta_True        dfcmpltPreLC4
# 87      3.0       15.0  dfcmpltPreLC4_SITE1_Boruta_True  dfcmpltPreLC4_SITE1
# 87      3.0       10.0  dfcmpltPreLC4_SITE2_Boruta_True  dfcmpltPreLC4_SITE2
# 251     7.0        3.0  dfcmpltPreLC4_SITE3_Boruta_True  dfcmpltPreLC4_SITE3
# 87      3.0       19.0  dfcmpltPreLC4_SITE4_Boruta_True  dfcmpltPreLC4_SITE4
# 169     5.0        2.0  dfcmpltPreLC4_SITE5_Boruta_True  dfcmpltPreLC4_SITE5
# 87      3.0       14.0  dfcmpltPreLC4_SITE6_Boruta_True  dfcmpltPreLC4_SITE6
# 87      3.0       18.0  dfcmpltPreLC4_SITE7_Boruta_True  dfcmpltPreLC4_SITE7
#
#          RunType          site              classifier  accuracy  \
# 87   Boruta_True        Global  RandomForestClassifier  0.688497
# 87   Boruta_True           LDN  RandomForestClassifier  0.804545
# 87   Boruta_True           MTL  RandomForestClassifier  0.688096
# 251  Boruta_True           SAN  RandomForestClassifier  0.926374
# 87   Boruta_True           RIO  RandomForestClassifier  0.981048
# 169  Boruta_True           LUS  RandomForestClassifier  0.717602
# 87   Boruta_True        Canada  RandomForestClassifier  0.698725
# 87   Boruta_True  NorthAmerica  RandomForestClassifier  0.697538
#
#      balanced_accuracy   roc_auc        f1    recall  sensitivity  \
# 87            0.638307  0.734955  0.501326  0.394488     0.394488
# 87            0.788571  0.880000  0.743492  0.720000     0.720000
# 87            0.592381  0.666842  0.400498  0.344762     0.344762
# 251           0.929394  0.956061  0.950426  0.925455     0.925455
# 87            0.946667  0.998462  0.988819  1.000000     1.000000
# 169           0.488213  0.419454  0.102991  0.072727     0.072727
# 87            0.597880  0.687070  0.406034  0.326795     0.326795
# 87            0.631497  0.751774  0.485046  0.396627     0.396627
#
#      specificity  precision       NPV       PPV
# 87      0.882126   0.691237  0.688649  0.691237
# 87      0.857143   0.793333  0.831429  0.793333
# 87      0.840000   0.480362  0.744137  0.480362
# 251     0.933333   0.981818  0.820000  0.981818
# 87      0.893333   0.978307  1.000000  0.978307
# 169     0.903698   0.208571  0.771361  0.208571
# 87      0.868966   0.540606  0.738110  0.540606
# 87      0.866367   0.626783  0.719036  0.626783

# %%
# # Create the ExcelWriter object
writer = pd.ExcelWriter('../OUTPUTS/prelim_preLongCOVID4_Brt_columns.xlsx', engine='xlsxwriter')
pd.DataFrame(lTopBrt)[lPrettyColsSite+['brt_md','brt_nTrue','Title']].sort_values('balanced_accuracy',ascending=False).to_excel(writer,sheet_name='Results')

for i,d in pd.DataFrame(lTopBrt).iterrows():
    tmpdataset = d['MainDataset']
    md = int(d['brt_md'])
    f = f'OUTPUT/MP/05-classifiers/DataV3/{tmpdataset}/FS_{tmpdataset}_Boruta_T1000_itrr500_th100_topR5_MD{md}.csv'
    dfeat = pd.read_csv(f)
    MPutils.getTrueFeatList(f,asDF=True).to_excel(writer, sheet_name=d['site'])
    


    # Write each dataframe to a different sheet
    # df1.to_excel(writer, sheet_name=d['site'])

#     # Save the Excel file
writer.close()

# %%
dfTmpTop
# Out:
#              MainDataset                            Title          site  \
# 87   dfcmpltPreLC4_SITE7  dfcmpltPreLC4_SITE7_Boruta_True  NorthAmerica
# 169  dfcmpltPreLC4_SITE7  dfcmpltPreLC4_SITE7_Boruta_True  NorthAmerica
# 251  dfcmpltPreLC4_SITE7  dfcmpltPreLC4_SITE7_Boruta_True  NorthAmerica
#
#                            date              classifier      RunType  cv  \
# 87   2024-05-06 11:20:32.414037  RandomForestClassifier  Boruta_True   5
# 169  2024-05-06 11:20:32.414037  RandomForestClassifier  Boruta_True   5
# 251  2024-05-06 11:20:32.414037  RandomForestClassifier  Boruta_True   5
#
#     FeatureSet  brt_nTrue  brt_nTop  brt_md                 param_clf  \
# 87         NaN       18.0      23.0     3.0  RandomForestClassifier()
# 169        NaN        9.0      13.0     5.0  RandomForestClassifier()
# 251        NaN        3.0       8.0     7.0  RandomForestClassifier()
#
#      param_clf__max_depth  param_clf__n_estimators  param_clf__random_state  \
# 87                   10.0                   1000.0                     42.0
# 169                  10.0                   1000.0                     42.0
# 251                  10.0                   1000.0                     42.0
#
#      param_clf__max_iter  param_clf__learning_rate  accuracy  \
# 87                   NaN                       NaN  0.697538
# 169                  NaN                       NaN  0.674691
# 251                  NaN                       NaN  0.666221
#
#      balanced_accuracy   roc_auc        f1    recall  sensitivity  \
# 87            0.631497  0.751774  0.485046  0.396627     0.396627
# 169           0.620732  0.690659  0.487352  0.428706     0.428706
# 251           0.615895  0.686167  0.483196  0.436784     0.436784
#
#      specificity  precision       NPV       PPV                 brt_params
# 87      0.866367   0.626783  0.719036  0.626783  T1000_itrr500_th100_topR5
# 169     0.812759   0.566064  0.716693  0.566064  T1000_itrr500_th100_topR5
# 251     0.795006   0.548038  0.715991  0.548038  T1000_itrr500_th100_topR5

# %%
s_query = f'{s_CMPLT} and param_clf__n_estimators==1000 and param_clf__max_depth==10 {s_brt}'
dfTmp = deepcopy(dfRes.query(s_query)).sort_values('balanced_accuracy',ascending=False)
print(s_query)
print(f"Max balanced accuracy {dfTmp['balanced_accuracy'].max()}")
# print(f"Max balanced accuracy {dfTmp['balanced_accuracy'].max()}")

dfTmp[lPrettyCols]
# Out:
# MainDataset=="dfcmpltPreLC4" and param_clf__n_estimators==1000 and param_clf__max_depth==10 and (RunType=="Boruta_True" or RunType=="Boruta_Top")
# Max balanced accuracy 0.6383068761244804
#        MainDataset      RunType              classifier  brt_nTrue  brt_nTop  \
# 87   dfcmpltPreLC4  Boruta_True  RandomForestClassifier       21.0      26.0
# 128  dfcmpltPreLC4   Boruta_Top  RandomForestClassifier       21.0      26.0
# 210  dfcmpltPreLC4   Boruta_Top  RandomForestClassifier       11.0      15.0
# 169  dfcmpltPreLC4  Boruta_True  RandomForestClassifier       11.0      15.0
# 292  dfcmpltPreLC4   Boruta_Top  RandomForestClassifier        3.0       7.0
# 190  dfcmpltPreLC4  Boruta_True           XGBClassifier       11.0      15.0
# 139  dfcmpltPreLC4   Boruta_Top           XGBClassifier       21.0      26.0
# 98   dfcmpltPreLC4  Boruta_True           XGBClassifier       21.0      26.0
# 149  dfcmpltPreLC4   Boruta_Top           XGBClassifier       21.0      26.0
# 180  dfcmpltPreLC4  Boruta_True           XGBClassifier       11.0      15.0
# 108  dfcmpltPreLC4  Boruta_True           XGBClassifier       21.0      26.0
# 200  dfcmpltPreLC4  Boruta_True           XGBClassifier       11.0      15.0
# 159  dfcmpltPreLC4   Boruta_Top           XGBClassifier       21.0      26.0
# 303  dfcmpltPreLC4   Boruta_Top           XGBClassifier        3.0       7.0
# 118  dfcmpltPreLC4  Boruta_True           XGBClassifier       21.0      26.0
# 313  dfcmpltPreLC4   Boruta_Top           XGBClassifier        3.0       7.0
# 323  dfcmpltPreLC4   Boruta_Top           XGBClassifier        3.0       7.0
# 231  dfcmpltPreLC4   Boruta_Top           XGBClassifier       11.0      15.0
# 221  dfcmpltPreLC4   Boruta_Top           XGBClassifier       11.0      15.0
# 241  dfcmpltPreLC4   Boruta_Top           XGBClassifier       11.0      15.0
# 251  dfcmpltPreLC4  Boruta_True  RandomForestClassifier        3.0       7.0
# 272  dfcmpltPreLC4  Boruta_True           XGBClassifier        3.0       7.0
# 262  dfcmpltPreLC4  Boruta_True           XGBClassifier        3.0       7.0
# 282  dfcmpltPreLC4  Boruta_True           XGBClassifier        3.0       7.0
#
#      accuracy  balanced_accuracy   roc_auc        f1    recall  sensitivity  \
# 87   0.688497           0.638307  0.734955  0.501326  0.394488     0.394488
# 128  0.686687           0.633692  0.742070  0.487581  0.376202     0.376202
# 210  0.661179           0.624555  0.704786  0.510488  0.447048     0.447048
# 169  0.652080           0.622142  0.692515  0.520314  0.476933     0.476933
# 292  0.638423           0.612040  0.673701  0.514927  0.483934     0.483934
# 190  0.624745           0.606599  0.640633  0.521692  0.518234     0.518234
# 139  0.628377           0.604509  0.670889  0.511344  0.488558     0.488558
# 98   0.622017           0.600768  0.662748  0.511561  0.497675     0.497675
# 149  0.622022           0.598428  0.666641  0.504531  0.483960     0.483960
# 180  0.617447           0.598176  0.643869  0.509245  0.504441     0.504441
# 108  0.616542           0.595822  0.654504  0.506620  0.495324     0.495324
# 200  0.611997           0.593665  0.635272  0.506151  0.504441     0.504441
# 159  0.611083           0.590517  0.654915  0.500630  0.490831     0.490831
# 303  0.612927           0.590501  0.644935  0.497086  0.481583     0.481583
# 118  0.610166           0.590152  0.640640  0.501235  0.493051     0.493051
# 313  0.611100           0.587812  0.637889  0.491957  0.474713     0.474713
# 323  0.609282           0.587471  0.633644  0.494392  0.481583     0.481583
# 231  0.607414           0.586262  0.634994  0.493142  0.483699     0.483699
# 221  0.599232           0.576391  0.638779  0.478854  0.465439     0.465439
# 241  0.596501           0.573736  0.625755  0.475742  0.463192     0.463192
# 251  0.581063           0.544072  0.579743  0.406994  0.364551     0.364551
# 272  0.573753           0.540771  0.567712  0.413574  0.380643     0.380643
# 262  0.572848           0.540046  0.571708  0.413246  0.380695     0.380695
# 282  0.567389           0.535482  0.567653  0.409058  0.380590     0.380590
#
#      specificity  precision       NPV       PPV  brt_md  \
# 87      0.882126   0.691237  0.688649  0.691237     3.0
# 128     0.891183   0.700128  0.684530  0.700128     3.0
# 210     0.802062   0.597700  0.688295  0.597700     5.0
# 169     0.767350   0.573788  0.690644  0.573788     5.0
# 292     0.740146   0.550738  0.685455  0.550738     7.0
# 190     0.694965   0.527421  0.687428  0.527421     5.0
# 139     0.720460   0.538558  0.680886  0.538558     3.0
# 98      0.703862   0.528477  0.679819  0.528477     3.0
# 149     0.712896   0.529610  0.676780  0.529610     3.0
# 180     0.691912   0.516846  0.680938  0.516846     5.0
# 108     0.696320   0.520051  0.676603  0.520051     3.0
# 200     0.682889   0.510727  0.677715  0.510727     5.0
# 159     0.690203   0.514026  0.672672  0.514026     3.0
# 303     0.699419   0.514164  0.671845  0.514164     7.0
# 118     0.687252   0.510566  0.672836  0.510566     3.0
# 313     0.700911   0.511370  0.669617  0.511370     7.0
# 323     0.693358   0.509230  0.670084  0.509230     7.0
# 231     0.688824   0.504068  0.670527  0.504068     5.0
# 221     0.687343   0.494579  0.661742  0.494579     5.0
# 241     0.684279   0.489948  0.660046  0.489948     5.0
# 251     0.723593   0.464663  0.633934  0.464663     7.0
# 272     0.700900   0.454443  0.632685  0.454443     7.0
# 262     0.699396   0.453476  0.632138  0.453476     7.0
# 282     0.690374   0.445713  0.629404  0.445713     7.0
#
#                     brt_params
# 87   T1000_itrr500_th100_topR5
# 128  T1000_itrr500_th100_topR5
# 210  T1000_itrr500_th100_topR5
# 169  T1000_itrr500_th100_topR5
# 292  T1000_itrr500_th100_topR5
# 190  T1000_itrr500_th100_topR5
# 139  T1000_itrr500_th100_topR5
# 98   T1000_itrr500_th100_topR5
# 149  T1000_itrr500_th100_topR5
# 180  T1000_itrr500_th100_topR5
# 108  T1000_itrr500_th100_topR5
# 200  T1000_itrr500_th100_topR5
# 159  T1000_itrr500_th100_topR5
# 303  T1000_itrr500_th100_topR5
# 118  T1000_itrr500_th100_topR5
# 313  T1000_itrr500_th100_topR5
# 323  T1000_itrr500_th100_topR5
# 231  T1000_itrr500_th100_topR5
# 221  T1000_itrr500_th100_topR5
# 241  T1000_itrr500_th100_topR5
# 251  T1000_itrr500_th100_topR5
# 272  T1000_itrr500_th100_topR5
# 262  T1000_itrr500_th100_topR5
# 282  T1000_itrr500_th100_topR5

# %% [markdown]
# # Difference between Boruta Selected Datasets

# %%
lbrt_7 = MPutils.getTrueFeatList(
    "OUTPUT/MP/05-classifiers/DataV3/dfcmplt/FS_dfcmplt_Boruta_T1000_itrr500_th100_topR5_MD7.csv"
)

lbrt_5 = MPutils.getTrueFeatList(
    "OUTPUT/MP/05-classifiers/DataV3/dfcmplt/FS_dfcmplt_Boruta_T1000_itrr500_th100_topR5_MD5.csv"
)

lbrt_3 = MPutils.getTrueFeatList(
    "OUTPUT/MP/05-classifiers/DataV3/dfcmplt/FS_dfcmplt_Boruta_T1000_itrr500_th100_topR5_MD3.csv"
)

len(lbrt_7), len(lbrt_5), len(lbrt_3)
# Out:
# (68, 81, 113)

# %%
set(lbrt_7).difference(set(lbrt_5))
# Out:
# set()

# %%
set(lbrt_5).difference(set(lbrt_7))
# Out:
# {'CD-covid_test_result_2',
#  'CD-gcs',
#  'CD-neurologic-other-1',
#  'CD-neurologic-other-4',
#  'CD-required_oxygen',
#  'CD-respiratory_rate',
#  'CD-severity_level___2',
#  'LABS-IND-basophil_count',
#  'LABS-IND-eosinophil',
#  'LABS-IND-pct',
#  'SYMPT-fever_38_0oc___2',
#  'SYMPT-night_sweats___2',
#  'SYMPT-runny_nose_rhinorrhea___2'}

# %%
set(lbrt_7).difference(set(lbrt_3))
# Out:
# set()

# %%
set(lbrt_3).difference(set(lbrt_5))
# Out:
# {'CD-covid_test_result_1',
#  'CD-covid_test_result_3',
#  'CD-hospitalized',
#  'CD-insomnia___1',
#  'CD-medication_received___4',
#  'CD-medication_received___5',
#  'CD-memory_problems___1',
#  'CD-respiratory-other-1',
#  'CD-severity_level___3',
#  'CD-type_of_care___2',
#  'HHX-Arterial Hypertension',
#  'HHX-Diabetes',
#  'HHX-OTHER-Sleep-disorder',
#  'HHX-Obesity',
#  'IMG-ctt',
#  'LAB-test-lung_function',
#  'LABS-IND-cpk',
#  'LABS-IND-inr',
#  'MED-Cardiovascular-agents',
#  'MED-Respiratory-tract-agents',
#  'SYMPT-cough___1',
#  'SYMPT-diarrhea___1',
#  'SYMPT-extremity_weakness_or_numb___1',
#  'SYMPT-fatigue___1',
#  'SYMPT-fever_38_0oc___1',
#  'SYMPT-joint_pain_arthralgia___1',
#  'SYMPT-muscle_aches_myalgia___1',
#  'SYMPT-nausea_vomiting___1',
#  'SYMPT-runny_nose_rhinorrhea___1',
#  'SYMPT-sore_throat___1',
#  'SYMPT-trouble_speaking_aphasia_d___2',
#  'SYMPT-weight_loss___1'}

# %%
set(lbrt_3).difference(set(lbrt_5))
# Out:
# {'CD-covid_test_result_1',
#  'CD-covid_test_result_3',
#  'CD-hospitalized',
#  'CD-insomnia___1',
#  'CD-medication_received___4',
#  'CD-medication_received___5',
#  'CD-memory_problems___1',
#  'CD-respiratory-other-1',
#  'CD-severity_level___3',
#  'CD-type_of_care___2',
#  'HHX-Arterial Hypertension',
#  'HHX-Diabetes',
#  'HHX-OTHER-Sleep-disorder',
#  'HHX-Obesity',
#  'IMG-ctt',
#  'LAB-test-lung_function',
#  'LABS-IND-cpk',
#  'LABS-IND-inr',
#  'MED-Cardiovascular-agents',
#  'MED-Respiratory-tract-agents',
#  'SYMPT-cough___1',
#  'SYMPT-diarrhea___1',
#  'SYMPT-extremity_weakness_or_numb___1',
#  'SYMPT-fatigue___1',
#  'SYMPT-fever_38_0oc___1',
#  'SYMPT-joint_pain_arthralgia___1',
#  'SYMPT-muscle_aches_myalgia___1',
#  'SYMPT-nausea_vomiting___1',
#  'SYMPT-runny_nose_rhinorrhea___1',
#  'SYMPT-sore_throat___1',
#  'SYMPT-trouble_speaking_aphasia_d___2',
#  'SYMPT-weight_loss___1'}

# %%
set(lbrt_5).difference(set(lbrt_3))
# Out:
# set()

# %%
set(lbrt_5).difference(set(lbrt_7))
# Out:
# {'CD-covid_test_result_2',
#  'CD-gcs',
#  'CD-neurologic-other-1',
#  'CD-neurologic-other-4',
#  'CD-required_oxygen',
#  'CD-respiratory_rate',
#  'CD-severity_level___2',
#  'LABS-IND-basophil_count',
#  'LABS-IND-eosinophil',
#  'LABS-IND-pct',
#  'SYMPT-fever_38_0oc___2',
#  'SYMPT-night_sweats___2',
#  'SYMPT-runny_nose_rhinorrhea___2'}

# %% [markdown]
# # Validation Results

# %%
dfVal = dfRes.query(f'{s_RF10} and {s_val}').sort_values('balanced_accuracy',ascending=False)
dfVal
# Out:
#            MainDataset                           Title          site  \
# 5  dfcmpltPreLC4_SITE4  dfcmpltPreLC4_SITE4_HoldoutVal           RIO
# 5  dfcmpltPreLC4_SITE4  dfcmpltPreLC4_SITE4_HoldoutVal           RIO
# 5  dfcmpltPreLC4_SITE1  dfcmpltPreLC4_SITE1_HoldoutVal           LDN
# 5  dfcmpltPreLC4_SITE3  dfcmpltPreLC4_SITE3_HoldoutVal           SAN
# 5  dfcmpltPreLC4_SITE1  dfcmpltPreLC4_SITE1_HoldoutVal           LDN
# 5  dfcmpltPreLC4_SITE3  dfcmpltPreLC4_SITE3_HoldoutVal           SAN
# 5  dfcmpltPreLC4_SITE7  dfcmpltPreLC4_SITE7_HoldoutVal  NorthAmerica
# 5        dfcmpltPreLC4        dfcmpltPreLC4_HoldoutVal        Global
# 5  dfcmpltPreLC4_SITE7  dfcmpltPreLC4_SITE7_HoldoutVal  NorthAmerica
# 5  dfcmpltPreLC4_SITE6  dfcmpltPreLC4_SITE6_HoldoutVal        Canada
# 5  dfcmpltPreLC4_SITE6  dfcmpltPreLC4_SITE6_HoldoutVal        Canada
# 5  dfcmpltPreLC4_SITE2  dfcmpltPreLC4_SITE2_HoldoutVal           MTL
# 5  dfcmpltPreLC4_SITE2  dfcmpltPreLC4_SITE2_HoldoutVal           MTL
# 5  dfcmpltPreLC4_SITE5  dfcmpltPreLC4_SITE5_HoldoutVal           LUS
# 5  dfcmpltPreLC4_SITE5  dfcmpltPreLC4_SITE5_HoldoutVal           LUS
#
#                          date              classifier     RunType  cv  \
# 5  2024-05-06 11:44:10.958993  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:44:08.270017  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:43:52.601321  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:44:06.063062  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:43:54.701532  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:44:04.053039  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:44:29.614930  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:43:49.648575  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:44:25.865340  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:44:22.804672  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:44:19.846220  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:44:01.682305  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:43:58.213916  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:44:13.912094  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:44:16.893733  RandomForestClassifier  HoldoutVal   5
#
#                                           FeatureSet  brt_nTrue  brt_nTop  \
# 5  FS_dfcmpltPreLC4_SITE4_Boruta_T1000_itrr500_th...        NaN       NaN
# 5  FS_dfcmpltPreLC4_Boruta_T1000_itrr500_th100_to...        NaN       NaN
# 5  FS_dfcmpltPreLC4_Boruta_T1000_itrr500_th100_to...        NaN       NaN
# 5  FS_dfcmpltPreLC4_SITE3_Boruta_T1000_itrr500_th...        NaN       NaN
# 5  FS_dfcmpltPreLC4_SITE1_Boruta_T1000_itrr500_th...        NaN       NaN
# 5  FS_dfcmpltPreLC4_Boruta_T1000_itrr500_th100_to...        NaN       NaN
# 5  FS_dfcmpltPreLC4_SITE7_Boruta_T1000_itrr500_th...        NaN       NaN
# 5  FS_dfcmpltPreLC4_Boruta_T1000_itrr500_th100_to...        NaN       NaN
# 5  FS_dfcmpltPreLC4_Boruta_T1000_itrr500_th100_to...        NaN       NaN
# 5  FS_dfcmpltPreLC4_SITE6_Boruta_T1000_itrr500_th...        NaN       NaN
# 5  FS_dfcmpltPreLC4_Boruta_T1000_itrr500_th100_to...        NaN       NaN
# 5  FS_dfcmpltPreLC4_SITE2_Boruta_T1000_itrr500_th...        NaN       NaN
# 5  FS_dfcmpltPreLC4_Boruta_T1000_itrr500_th100_to...        NaN       NaN
# 5  FS_dfcmpltPreLC4_Boruta_T1000_itrr500_th100_to...        NaN       NaN
# 5  FS_dfcmpltPreLC4_SITE5_Boruta_T1000_itrr500_th...        NaN       NaN
#
#    brt_md                 param_clf  param_clf__max_depth  \
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
#
#    param_clf__n_estimators  param_clf__random_state  param_clf__max_iter  \
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
#
#    param_clf__learning_rate  accuracy  balanced_accuracy   roc_auc        f1  \
# 5                       NaN  1.000000           1.000000  1.000000  1.000000
# 5                       NaN  0.980645           0.940000  0.979231  0.988679
# 5                       NaN  0.877273           0.878571  0.930000  0.858608
# 5                       NaN  0.852747           0.832727  0.898182  0.901010
# 5                       NaN  0.827273           0.829286  0.940000  0.779243
# 5                       NaN  0.850549           0.767576  0.895152  0.901485
# 5                       NaN  0.744620           0.684352  0.771235  0.564820
# 5                       NaN  0.711287           0.679182  0.763237  0.588057
# 5                       NaN  0.693212           0.623336  0.728322  0.466846
# 5                       NaN  0.689264           0.581675  0.673098  0.367057
# 5                       NaN  0.686077           0.577972  0.710466  0.364025
# 5                       NaN  0.665592           0.555536  0.606742  0.327077
# 5                       NaN  0.670630           0.545394  0.662683  0.291222
# 5                       NaN  0.746854           0.514073  0.600067  0.134380
# 5                       NaN  0.705357           0.481014  0.544066  0.097619
#
#      recall  sensitivity  specificity  precision       NPV       PPV  \
# 5  1.000000     1.000000     1.000000   1.000000  1.000000  1.000000
# 5  1.000000     1.000000     0.880000   0.977778  1.000000  0.977778
# 5  0.900000     0.900000     0.857143   0.845000  0.941667  0.845000
# 5  0.865455     0.865455     0.800000   0.945455  0.640000  0.945455
# 5  0.830000     0.830000     0.828571   0.805000  0.906667  0.805000
# 5  0.901818     0.901818     0.633333   0.909382  0.763333  0.909382
# 5  0.466980     0.466980     0.901723   0.719913  0.750855  0.719913
# 5  0.521682     0.521682     0.836683   0.682757  0.726625  0.682757
# 5  0.371765     0.371765     0.874906   0.633154  0.711257  0.633154
# 5  0.290000     0.290000     0.873349   0.518000  0.727887  0.518000
# 5  0.285000     0.285000     0.870944   0.504324  0.725522  0.504324
# 5  0.269048     0.269048     0.842025   0.437266  0.721369  0.437266
# 5  0.218730     0.218730     0.872057   0.448111  0.714268  0.448111
# 5  0.092727     0.092727     0.935420   0.363810  0.781001  0.363810
# 5  0.074545     0.074545     0.887482   0.150000  0.767685  0.150000
#
#   brt_params
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN

# %%
dfVal = dfVal.sort_values(['FeatureSet','MainDataset'])
dfVal
# Out:
#            MainDataset                           Title          site  \
# 5        dfcmpltPreLC4        dfcmpltPreLC4_HoldoutVal        Global
# 5  dfcmpltPreLC4_SITE1  dfcmpltPreLC4_SITE1_HoldoutVal           LDN
# 5  dfcmpltPreLC4_SITE2  dfcmpltPreLC4_SITE2_HoldoutVal           MTL
# 5  dfcmpltPreLC4_SITE3  dfcmpltPreLC4_SITE3_HoldoutVal           SAN
# 5  dfcmpltPreLC4_SITE4  dfcmpltPreLC4_SITE4_HoldoutVal           RIO
# 5  dfcmpltPreLC4_SITE5  dfcmpltPreLC4_SITE5_HoldoutVal           LUS
# 5  dfcmpltPreLC4_SITE6  dfcmpltPreLC4_SITE6_HoldoutVal        Canada
# 5  dfcmpltPreLC4_SITE7  dfcmpltPreLC4_SITE7_HoldoutVal  NorthAmerica
# 5  dfcmpltPreLC4_SITE1  dfcmpltPreLC4_SITE1_HoldoutVal           LDN
# 5  dfcmpltPreLC4_SITE2  dfcmpltPreLC4_SITE2_HoldoutVal           MTL
# 5  dfcmpltPreLC4_SITE3  dfcmpltPreLC4_SITE3_HoldoutVal           SAN
# 5  dfcmpltPreLC4_SITE4  dfcmpltPreLC4_SITE4_HoldoutVal           RIO
# 5  dfcmpltPreLC4_SITE5  dfcmpltPreLC4_SITE5_HoldoutVal           LUS
# 5  dfcmpltPreLC4_SITE6  dfcmpltPreLC4_SITE6_HoldoutVal        Canada
# 5  dfcmpltPreLC4_SITE7  dfcmpltPreLC4_SITE7_HoldoutVal  NorthAmerica
#
#                          date              classifier     RunType  cv  \
# 5  2024-05-06 11:43:49.648575  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:43:52.601321  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:43:58.213916  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:44:04.053039  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:44:08.270017  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:44:13.912094  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:44:19.846220  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:44:25.865340  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:43:54.701532  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:44:01.682305  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:44:06.063062  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:44:10.958993  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:44:16.893733  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:44:22.804672  RandomForestClassifier  HoldoutVal   5
# 5  2024-05-06 11:44:29.614930  RandomForestClassifier  HoldoutVal   5
#
#                                           FeatureSet  brt_nTrue  brt_nTop  \
# 5  FS_dfcmpltPreLC4_Boruta_T1000_itrr500_th100_to...        NaN       NaN
# 5  FS_dfcmpltPreLC4_Boruta_T1000_itrr500_th100_to...        NaN       NaN
# 5  FS_dfcmpltPreLC4_Boruta_T1000_itrr500_th100_to...        NaN       NaN
# 5  FS_dfcmpltPreLC4_Boruta_T1000_itrr500_th100_to...        NaN       NaN
# 5  FS_dfcmpltPreLC4_Boruta_T1000_itrr500_th100_to...        NaN       NaN
# 5  FS_dfcmpltPreLC4_Boruta_T1000_itrr500_th100_to...        NaN       NaN
# 5  FS_dfcmpltPreLC4_Boruta_T1000_itrr500_th100_to...        NaN       NaN
# 5  FS_dfcmpltPreLC4_Boruta_T1000_itrr500_th100_to...        NaN       NaN
# 5  FS_dfcmpltPreLC4_SITE1_Boruta_T1000_itrr500_th...        NaN       NaN
# 5  FS_dfcmpltPreLC4_SITE2_Boruta_T1000_itrr500_th...        NaN       NaN
# 5  FS_dfcmpltPreLC4_SITE3_Boruta_T1000_itrr500_th...        NaN       NaN
# 5  FS_dfcmpltPreLC4_SITE4_Boruta_T1000_itrr500_th...        NaN       NaN
# 5  FS_dfcmpltPreLC4_SITE5_Boruta_T1000_itrr500_th...        NaN       NaN
# 5  FS_dfcmpltPreLC4_SITE6_Boruta_T1000_itrr500_th...        NaN       NaN
# 5  FS_dfcmpltPreLC4_SITE7_Boruta_T1000_itrr500_th...        NaN       NaN
#
#    brt_md                 param_clf  param_clf__max_depth  \
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
# 5     NaN  RandomForestClassifier()                  10.0
#
#    param_clf__n_estimators  param_clf__random_state  param_clf__max_iter  \
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
# 5                   1000.0                     42.0                  NaN
#
#    param_clf__learning_rate  accuracy  balanced_accuracy   roc_auc        f1  \
# 5                       NaN  0.711287           0.679182  0.763237  0.588057
# 5                       NaN  0.877273           0.878571  0.930000  0.858608
# 5                       NaN  0.670630           0.545394  0.662683  0.291222
# 5                       NaN  0.850549           0.767576  0.895152  0.901485
# 5                       NaN  0.980645           0.940000  0.979231  0.988679
# 5                       NaN  0.746854           0.514073  0.600067  0.134380
# 5                       NaN  0.686077           0.577972  0.710466  0.364025
# 5                       NaN  0.693212           0.623336  0.728322  0.466846
# 5                       NaN  0.827273           0.829286  0.940000  0.779243
# 5                       NaN  0.665592           0.555536  0.606742  0.327077
# 5                       NaN  0.852747           0.832727  0.898182  0.901010
# 5                       NaN  1.000000           1.000000  1.000000  1.000000
# 5                       NaN  0.705357           0.481014  0.544066  0.097619
# 5                       NaN  0.689264           0.581675  0.673098  0.367057
# 5                       NaN  0.744620           0.684352  0.771235  0.564820
#
#      recall  sensitivity  specificity  precision       NPV       PPV  \
# 5  0.521682     0.521682     0.836683   0.682757  0.726625  0.682757
# 5  0.900000     0.900000     0.857143   0.845000  0.941667  0.845000
# 5  0.218730     0.218730     0.872057   0.448111  0.714268  0.448111
# 5  0.901818     0.901818     0.633333   0.909382  0.763333  0.909382
# 5  1.000000     1.000000     0.880000   0.977778  1.000000  0.977778
# 5  0.092727     0.092727     0.935420   0.363810  0.781001  0.363810
# 5  0.285000     0.285000     0.870944   0.504324  0.725522  0.504324
# 5  0.371765     0.371765     0.874906   0.633154  0.711257  0.633154
# 5  0.830000     0.830000     0.828571   0.805000  0.906667  0.805000
# 5  0.269048     0.269048     0.842025   0.437266  0.721369  0.437266
# 5  0.865455     0.865455     0.800000   0.945455  0.640000  0.945455
# 5  1.000000     1.000000     1.000000   1.000000  1.000000  1.000000
# 5  0.074545     0.074545     0.887482   0.150000  0.767685  0.150000
# 5  0.290000     0.290000     0.873349   0.518000  0.727887  0.518000
# 5  0.466980     0.466980     0.901723   0.719913  0.750855  0.719913
#
#   brt_params
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN
# 5        NaN

# %%
sGlobal = 'FS_dfcmpltPreLC4_Boruta_T1000_itrr500_th100_topR5_MD3'

dfVal['FeatureSetSpecific'] = dfVal['FeatureSet'].apply(lambda x:  'Global' if x == sGlobal else 'Site')

# %%
# # Create the ExcelWriter object
writer = pd.ExcelWriter('../OUTPUTS/prelim_preLongCOVID4_Val.xlsx', engine='xlsxwriter')
dfVal[lPrettyColsSite+['brt_md','brt_nTrue','Title','FeatureSet','FeatureSetSpecific']].sort_values('balanced_accuracy',ascending=False).to_excel(writer,sheet_name='Results')


for i,d in pd.DataFrame(dfVal.sort_values([])).iterrows():
    tmpFS = d['FeatureSet']
    sheetName = f"{d['FeatureSetSpecific']} Feat - {d['site']}"
        
    tmpMainData = d['MainDataset']
    
    dFeat = pd.read_csv(f'OUTPUT/MP/05-classifiers/DataV3/{tmpMainData}/FR_{tmpMainData}_HoldoutVal_{tmpFS}.csv')
    # f = f'OUTPUT/MP/05-classifiers/DataV3/{tmpdataset}/FS_{tmpdataset}_Boruta_T1000_itrr500_th100_topR5_MD{md}.csv'
    # dfeat = pd.read_csv(f)
    
    # MPutils.getTrueFeatList(f,asDF=True).to_excel(writer, sheet_name=d['site'])
    dFeat.to_excel(writer,sheet_name=sheetName)


    # Write each dataframe to a different sheet
    # df1.to_excel(writer, sheet_name=d['site'])

#     # Save the Excel file
writer.close()
